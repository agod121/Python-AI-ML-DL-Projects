# %%
data_url = 'https://slickdeals.net/f/15934510-kyrie-infinity-8-basketball-shoe-52-78?src=frontpage#commentsBox'

# %%
import requests

# %%
reviews = requests.get(data_url)

# %%
text = reviews.text

# %%
text
# Out:
# '<!DOCTYPE html>\n<!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html class="no-js"> <!--<![endif]-->\n  <head>\n        <script>var googletag = googletag || {};\n      googletag.cmd = googletag.cmd || [];\n    </script>\n            <link rel="preload" href="/cashback/offers/stores/?displayPage=showthread&amp;threadId=15934510&amp;storeIds=766" as="fetch" crossorigin="anonymous">\n<script>\n    (function(w){\'use strict\';const requestedUrls=[];const keyData={};function fetch(key,url,callback){if(url[0]!==\'/\'){throw new Error(\'URL is malformed\')}if(requestedUrls.indexOf(url)>-1){throw new Error(\'Provided url has already been requested\');}if(key in keyData){throw new Error(\'Specified key already exists\');}processUrl(key,url,callback)};function isKeyLoaded(key){if(key in keyData){return keyData[key].loaded}throw new Error(\'Either no key was provided, or no key-url pair exists\');};function getData(key,callback){if(key in keyData){if(keyData[key].loaded===true){if(typeof callback===\'function\'){return callback(keyData[key].data)}else{return keyData[key].data}}else if(keyData[key].loaded===false&&typeof callback===\'function\'){keyData[key].callbacks.push(callback)}else{throw new Error(\'Data is currently unavailable for key: \'+key);}}else{throw new Error(\'Either no key was provided, or no key-url pair exists\');}};function addCallback(key,callback){if(typeof callback===\'function\'&&key in keyData){if(isKeyLoaded(key)){return callback(getData(key))}keyData[key].callbacks.push(callback)}else{if(typeof callback!==\'function\'){throw new Error(\'Expected a valid callback\');}throw new Error(\'Key does not exist\');}};function dumpLoadTable(){console.info(keyData,requestedUrls)};function processUrl(key,url,callback){keyData[key]={\'loaded\':false,\'url\':url,\'callbacks\':[],};requestedUrls.push(url);if(typeof callback===\'function\'){keyData[key].callbacks.push(callback)}if(typeof window.fetch!==\'undefined\'){window.fetch(url).then(handleFetchResponse.bind(null,key))}else{const xmlRequest=new XMLHttpRequest();xmlRequest.open(\'GET\',url);xmlRequest.addEventListener(\'load\',handleXhrResponse.bind(null,key,xmlRequest));xmlRequest.send()}}function handleFetchResponse(key,response){if(response.ok){response.text().then(handleFetchText.bind(null,key))}else{throw new Error(\'Url failed to fetch - bad request\');}}function handleFetchText(key,text){keyData[key].data=text;keyData[key].loaded=true;if(\'callbacks\'in keyData[key]&&keyData[key].callbacks.length){for(let i=0;i<keyData[key].callbacks.length;i++){keyData[key].callbacks[i](text);delete keyData[key].callbacks[i]}}}function handleXhrResponse(key,xmlRequest){if(xmlRequest.status>=400){throw new Error(\'Url failed to fetch - bad request\');}handleFetchText.call(null,key,xmlRequest.response)}function hasKey(key){return key in keyData}if(!w.hasOwnProperty(\'immediateFetch\')){w.immediateFetch={\'fetch\':fetch,\'isKeyLoaded\':isKeyLoaded,\'getData\':getData,\'addCallback\':addCallback,\'dumpLoadTable\':dumpLoadTable,\'hasKey\':hasKey,}}}(window));\n</script>\n<script>\n            window.immediateFetch.fetch(\'loyaltyOffers\', \'\\/cashback\\/offers\\/stores\\/\\u003FdisplayPage\\u003Dshowthread\\u0026threadId\\u003D15934510\\u0026storeIds\\u003D766\');\n    </script>\n        <link rel="preload" href="/ajax/bSubNavPlacement.php?section=showthread&amp;url=%2Ff%2F15934510-kyrie-infinity-8-basketball-shoe-52-78%3Fsrc%3Dfrontpage" as="fetch" crossorigin="anonymous">\n  <script>\n    window.immediateFetch.fetch(\'banner\', \'/ajax/bSubNavPlacement.php?section=showthread&url=%2Ff%2F15934510-kyrie-infinity-8-basketball-shoe-52-78%3Fsrc%3Dfrontpage\');\n  </script>\n          <script>\nArray.from||(Array.from=function(){var r=Object.prototype.toString,n=function(n){return"function"==typeof n ...

# %%
import nltk

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sid =  SentimentIntensityAnalyzer()

# %%
scores = sid.polarity_scores(text)

# %%
scores
# Out:
# {'compound': 1.0, 'neg': 0.006, 'neu': 0.945, 'pos': 0.049}
